# %%
from bs4 import BeautifulSoup
import requests
from urllib.parse import urljoin
import time
import json

BASE_URL = "https://developer.bitmovin.com"
DOC_TYPE = ["/streams/docs", "/playback/docs", "/encoding/docs"]

def get_sidebar_links():
    for doc_type_link in DOC_TYPE:
        response = requests.get(BASE_URL + doc_type_link)
        soup = BeautifulSoup(response.text, "html.parser")

        # Extract all <a> tags in the sidebar that have hrefs pointing to docs
        sidebar_links = soup.select("a.rm-Sidebar-link[href^='/']")
        
        urls = []
        for link in sidebar_links:
            href = link.get("href")
            if href and "/docs/" in href:
                full_url = urljoin(BASE_URL, href)
                urls.append(full_url)
    
    return list(set(urls))  # remove duplicates

links = get_sidebar_links()

# %%
def extract_article(url):
    res = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})
    soup = BeautifulSoup(res.text, "html.parser")

    # Target the 'dehydrated' content blocks inside the page
    dehydrated_blocks = soup.find_all("div", attrs={"dehydrated": lambda v: v is not None})
    if not dehydrated_blocks:
        return None

    # Try to find the main title
    title_tag = soup.find("h1")
    title = title_tag.get_text(strip=True) if title_tag else "Untitled"

    # Extract all text from the dehydrated blocks
    text_parts = []
    for div in dehydrated_blocks:
        text_parts.append(div.get_text(separator="\n", strip=True))

    full_text = "\n\n".join(text_parts)

    # Optional: Extract media links
    imgs = [img["src"] for img in soup.find_all("img") if img.get("src")]
    videos = [vid["src"] for vid in soup.find_all("video") if vid.get("src")]

    return {
        "url": url,
        "title": title,
        "text": full_text,
        "images": imgs,
        "videos": videos
    }



parsed_docs = []
for link in links:
    print(f"⏳ Fetching: {link}")
    try:
        article_data = extract_article(link)
        if article_data:
            parsed_docs.append(article_data)
    except Exception as e:
        print(f"⚠️ Error: {e}")
    time.sleep(0.5)  # Be respectful to the server

# Save results as JSON
with open("parsed_docs.json", "w", encoding="utf-8") as f:
    json.dump(parsed_docs, f, indent=2, ensure_ascii=False)
# Out:
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/supported-output-options-for-per-title-encoding
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/understanding-the-bitmovin-encoding-object-model
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/muting-and-unmuting-webhooks
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/zixi-inputs
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/contribution-devices
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/bitmovin-approved-contribution-devices
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/managing-your-payment-billing-details
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/live-to-vod-workflows
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/using-per-title-encoding-with-ssai
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/creating-access-and-secret-keys-for-google-cloud-storage
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/changes-to-fmp4-outputs-in-encoder-version-21530
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/encoder-200-2490
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/go-sdk
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/creating-a-per-title-encoding
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/creating-an-s3-role-based-encoding-input-or-output-with-the-bitmovin-api
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/understanding-the-default-timestamp-offset-for-ts-muxings
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/using-speke-for-drm
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/retrieving-vod-encoding-information-with-the-bitmovin-api
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/finding-and-understanding-your-encoding-ids
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/documentation
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/aws-s3-simple-live-outputs
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/deinterlacing-content-with-bitmovin-encoding
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/setting-up-an-akamai-netstorage-output
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/setting-up-cors-for-your-google-cloud-storage-bucket
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/vp9-presets-live
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/adapting-automatically-to-different-source-files-using-stream-conditions
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/automating-video-editing-with-bitmovin-encoding-api
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/akamai-live-outputs
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/rest-api-services-100-1490
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/editing-codec-configurations
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/using-bitmovin-cloud-connect-with-gcp
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/srt-api-configuration
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/thumbnail-generation-support-for-vod-encoding
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/encoding-templates-for-live-standby-pools
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/managing-your-organization-team-access
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/sign-up-through-aws-marketplace
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/creating-fairplay-drm-protected-content
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/encoder-21000-21490
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/creating-primetime-drm-protected-content
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/downloading-the-encoded-video-directly-to-a-computer
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/creating-progressive-mov-mp4-and-ts-outputs
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/choosing-the-right-encoder-version
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/rest-api-services-12000-12490
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/using-simple-s3-output-in-the-dashboard
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/aws-s3-access-key-live-outputs
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/understanding-why-segment-duration-differs-from-the-defined-target
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/live-inputs
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/srt-inputs
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/akamai-netstorage-for-live-outputs
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/automatic-shutdown-options
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/creating-an-akamai-netstorage-upload-account
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/understanding-mpeg-cenc-clearkey-encryption
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/creating-widevine-drm-protected-content
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/manifest-generator-v2
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/bitmovin-cloud-connect
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/live-encoding-standby-pools
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/best-practice-guide-rest-api-5xx-errors
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/supported-hdr-formats-and-conversions-in-bitmovin-encoder
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/supported-input-and-output-storages
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/integrating-bitmovin-encoder-with-pallycon-multi-drm
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/creating-live-standby-pools
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/rtmp-api-configuration
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/using-nagra-nexguard-filemarker-a-b-watermarking
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/dynamic-range-format-presets
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/creating-multi-drm-protected-content-with-intertrust-expressplay
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/separating-and-combining-audio-streams
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/creating-an-encoding-with-hardware-acceleration
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/required-permissions-for-gcs-buckets-for-encoding-input-and-output
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/stream-conditions
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/live-heartbeat
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/rtmp-live-stream-input-requirements
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/per-title-configuration-options
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/creating-mpeg-cenc-clearkey-content
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/vp9-presets
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/using-aws-s3-role-based-outputs
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/h264-presets-live
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/overview-per-title-encoding
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/live-outputs
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/nodejs-javascript-sdk
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/bitmovin-cdn-output
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/c-sdk
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/sdks
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/live-encoding-with-hls-scte-35-and-ssai
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/changing-your-login-credentials
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/required-permissions-for-s3-buckets-for-encoding-input-and-output
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/drm-removal-from-a-stream
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/h264-presets
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/glossary
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/python-sdk
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/optimizing-your-h264-codec-configuration-for-different-use-cases
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/h265-presets
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/reducing-turnaround-time-for-vod-encodings
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/incompatible-output-frame-rates
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/understanding-media-err-decode-in-google-chrome-with-encoded-content
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/obs-studio-contribution-encoder
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/encoder-1243-1560
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/get-started-with-the-bitmovin-api
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/rest-api-services-1500-1990
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/h265-presets-live
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/live-encoding-captions-generation-with-azure-speech-services
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/azure-buckets-for-live-outputs
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/protecting-your-content-with-bitmovin-and-vualto-drm
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/default-vs-custom-manifest
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/supported-formats-storage
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/troubleshooting-output-transfer-failures
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/digital-rights-management-drm-overview
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/gcp-buckets-for-live-outputs
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/managing-api-keys
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/creating-dolby-digital-plus-encodings
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/creating-combined-multi-drm-protected-content
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/rtmp-inputs
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/pitch-shifting-in-encoded-audio-when-changing-tracks
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/using-akamai-object-storage-for-encoding
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/creating-dtshd-dtsx-encodings
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/creating-playready-drm-protected-content
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/supported-input-and-output-formats
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/aws-live-outputs
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/understanding-the-different-encoding-states
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/stitching-and-trimming-getting-started
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/how-to-implement-a-live-to-vod-workflow-with-the-bitmovin-api
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/how-live-standby-pools-work
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/creating-an-s3-encoding-input-or-output-with-the-bitmovin-api
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/using-bitmovin-cloud-connect-with-aws
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/live-encoding-with-broadpeak-io
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/encoder-22000-22490
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/using-per-title-encodings-with-drm-solutions
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/live-standby-pools-management
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/setting-up-an-akamai-netstorage-input
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/specifying-required-resolutions-for-per-title-encoding
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/using-pre-warmed-encoder-pools
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/using-bitmovin-cloud-connect-with-azure
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/the-bitmovin-dashboard
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/live-dvr-best-practice
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/how-live-encoding-works
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/understanding-hls-aes-encryption
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/akamai-msl4-live-outputs
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/live-encoding-with-yospace
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/java-sdk
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/encoder-2500-2990
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/reducing-turnaround-times-for-short-form-video-content
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/enabling-2-step-verification
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/encoding-templates
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/difference-between-inputstreams-and-direct-input-file-definition-on-a-stream
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/adjusting-the-per-title-algorithm-for-custom-requirements
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/configuring-codec-to-maintain-original-video-aspect-ratio
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/rest-api-services-11000-11500
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/encoder-21500-21990
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/preview-and-programme-dvr-intervals-with-timeshift
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/configuring-an-aws-s3-bucket-for-content-playback-testing
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/managing-your-subscription
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/bitmovin-encoder-lifecycle
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/performance-and-optimization
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/enable-usage-reports
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/rest-api-services-11500-11990
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/php-sdk
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/retrying-transfer-errors-with-re-transfer-for-successful-encoding-jobs
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/creating-manifests-with-the-bitmovin-api
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/constraining-bandwidth-in-per-title-encoding
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/bitmovin-video-encoder-v1-to-v2-migration-guide
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/bitmovin-bug-bounty-program
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/encoder-release-notes
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/troubleshooting-s3-output-failures-with-correct-credentials
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/managing-multiple-organizations
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/live-encoding-with-aws-mediatailor
# ⏳ Fetching: https://developer.bitmovin.com/encoding/docs/aws-s3-role-based-live-outputs
